# %% [markdown]
# # Python Basic Assignment_3

# %% [markdown]
# ### 1. What are the benefits of including roles in the programmes?

# %% [markdown]
# ##### ANSWER:
#
# The following are the benefits of including roles in the programmes:
#
# - Reduces the need to duplicate code.
#
# - Makes programmes shorter.
#
# - Makes programmes easier to read.
#
# - Makes programmes easier to update.

# %% [markdown]
# ### 2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# ##### ANSWER:
#
# The code in a function runs when it's called.

# %% [markdown]
# ### 3. What statement causes a feature to be created?

# %% [markdown]
# ##### ANSWER:
#
# The def statement causes a feature to be created.

# %% [markdown]
# ### 4. What is the distinction between a function and a call to a function?

# %% [markdown]
# ##### ANSWER:
#
# A function consists of the def statement and the code in its def clause.
#
# A call to a function is what moves the program execution into the function, and the function call evaluates to the function’s return value.

# %% [markdown]
# ### 5. In a Python application, how many global scopes are there? How many local scopes are there?

# %% [markdown]
# ##### ANSWER:
#
# In a Python Application, there is one global scope and multiple local scopes as a separate scope is created whenever a function is called.

# %% [markdown]
# ### 6. When a function call returns, what happens to variables in the local scope?

# %% [markdown]
# ##### ANSWER:
#
# When a function returns, the local scope is destroyed, and all the variables in it are forgotten.

# %% [markdown]
# ### 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# ##### ANSWER:
#
# A return value is the value that a function call evaluates to. Yes, it is possible to have a return value in an expression.

# %% [markdown]
# ### 8. What is the return value of a call to a function that does not have a return statement?

# %% [markdown]
# ##### ANSWER:
#
# The return value of a call to a function that does not have a return statement is None.

# %% [markdown]
# ### 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# ##### ANSWER:
#
# You can make a function variable refer to the global variable by using the global statement.

# %% [markdown]
# ### 10. What data form does None belong to?

# %% [markdown]
# ##### ANSWER:
#
# The data form None belongs to is NoneType.

# %% [markdown]
# ### 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# ##### ANSWER:
#
# The sentence import areallyourpetsnamederic imports a module named areallyourpetsnamederic.

# %% [markdown]
# ### 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# ##### ANSWER:
#
# This feature can be called with spam.bacon()

# %% [markdown]
# ### 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# ##### ANSWER:
#
# To save a programme from crashing if it encounters an error, you can place the line of code that might cause an error in a try clause.

# %% [markdown]
# ### 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# ##### ANSWER:
#
# The code that could potentially cause an error goes in the try clause.
#
# The code that executes if an error happens goes in the except clause.
